# %% [markdown]
# # task 1

# %% [markdown]
# # liberies for preprocessing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.model_selection import train_test_split
from sklearn import preprocessing 
import sklearn.metrics as me
import warnings 
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.model_selection import train_test_split
from sklearn import preprocessing

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# # task 1.2

# %% [markdown]
# # import data¶

# %%
data=pd.read_csv('DS2_C5_S1_Income_Data_Practice.csv')

# %%
data.shape
# Out:
# (32561, 14)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32561 non-null  int64
#  1   WorkClass       32561 non-null  object
#  2   Fnlwgt          32561 non-null  int64
#  3   Education       32561 non-null  object
#  4   Education_Num   32561 non-null  int64
#  5   Marital_Status  32561 non-null  object
#  6   Occupation      32561 non-null  object
#  7   Relationship    32561 non-null  object
#  8   Gender          32561 non-null  object
#  9   Capital_Gain    32561 non-null  int64
#  10  Capital_Loss    32561 non-null  int64
#  11  Hours_Per_Week  32561 non-null  int64
#  12  Native_Country  32561 non-null  object
#  13  Income_Bracket  32561 non-null  object
# dtypes: int64(6), object(8)
# memory usage: 3.5+ MB

# %%
data.columns
# Out:
# Index(['Age', 'WorkClass', 'Fnlwgt', 'Education', 'Education_Num',
#        'Marital_Status', 'Occupation', 'Relationship', 'Gender',
#        'Capital_Gain', 'Capital_Loss', 'Hours_Per_Week', 'Native_Country',
#        'Income_Bracket'],
#       dtype='object')

# %%
data.describe()
# Out:
#                 Age        Fnlwgt  Education_Num  Capital_Gain  Capital_Loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        Hours_Per_Week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
data.isnull().sum()
# Out:
# Age               0
# WorkClass         0
# Fnlwgt            0
# Education         0
# Education_Num     0
# Marital_Status    0
# Occupation        0
# Relationship      0
# Gender            0
# Capital_Gain      0
# Capital_Loss      0
# Hours_Per_Week    0
# Native_Country    0
# Income_Bracket    0
# dtype: int64

# %% [markdown]
# # task 2

# %% [markdown]
# # STRUCTURE OF DATA

# %%
data.shape
# Out:
# (32561, 14)

# %%
data.shape
# Out:
# (32561, 14)

# %%
data.head()
# Out:
#    Age          WorkClass  Fnlwgt   Education  Education_Num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         Marital_Status          Occupation    Relationship   Gender  \
# 0        Never-married        Adm-clerical   Not-in-family     Male
# 1   Married-civ-spouse     Exec-managerial         Husband     Male
# 2             Divorced   Handlers-cleaners   Not-in-family     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Female
#
#    Capital_Gain  Capital_Loss  Hours_Per_Week  Native_Country Income_Bracket
# 0          2174             0              40   United-States          <=50K
# ...

# %%
data.head()
# Out:
#    Age          WorkClass  Fnlwgt   Education  Education_Num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         Marital_Status          Occupation    Relationship   Gender  \
# 0        Never-married        Adm-clerical   Not-in-family     Male
# 1   Married-civ-spouse     Exec-managerial         Husband     Male
# 2             Divorced   Handlers-cleaners   Not-in-family     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Female
#
#    Capital_Gain  Capital_Loss  Hours_Per_Week  Native_Country Income_Bracket
# 0          2174             0              40   United-States          <=50K
# ...

# %%
data.tail()
# Out:
#        Age      WorkClass  Fnlwgt    Education  Education_Num  \
# 32556   27        Private  257302   Assoc-acdm             12
# 32557   40        Private  154374      HS-grad              9
# 32558   58        Private  151910      HS-grad              9
# 32559   22        Private  201490      HS-grad              9
# 32560   52   Self-emp-inc  287927      HS-grad              9
#
#             Marital_Status          Occupation Relationship   Gender  \
# 32556   Married-civ-spouse        Tech-support         Wife   Female
# 32557   Married-civ-spouse   Machine-op-inspct      Husband     Male
# 32558              Widowed        Adm-clerical    Unmarried   Female
# 32559        Never-married        Adm-clerical    Own-child     Male
# 32560   Married-civ-spouse     Exec-managerial         Wife   Female
#
#        Capital_Gain  Capital_Loss  Hours_Per_Week  Native_Country  \
# 32556             0             0              38   United-States
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32561 non-null  int64
#  1   WorkClass       32561 non-null  object
#  2   Fnlwgt          32561 non-null  int64
#  3   Education       32561 non-null  object
#  4   Education_Num   32561 non-null  int64
#  5   Marital_Status  32561 non-null  object
#  6   Occupation      32561 non-null  object
#  7   Relationship    32561 non-null  object
#  8   Gender          32561 non-null  object
#  9   Capital_Gain    32561 non-null  int64
#  10  Capital_Loss    32561 non-null  int64
#  11  Hours_Per_Week  32561 non-null  int64
#  12  Native_Country  32561 non-null  object
#  13  Income_Bracket  32561 non-null  object
# dtypes: int64(6), object(8)
# memory usage: 3.5+ MB

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32561 non-null  int64
#  1   WorkClass       32561 non-null  object
#  2   Fnlwgt          32561 non-null  int64
#  3   Education       32561 non-null  object
#  4   Education_Num   32561 non-null  int64
#  5   Marital_Status  32561 non-null  object
#  6   Occupation      32561 non-null  object
#  7   Relationship    32561 non-null  object
#  8   Gender          32561 non-null  object
#  9   Capital_Gain    32561 non-null  int64
#  10  Capital_Loss    32561 non-null  int64
#  11  Hours_Per_Week  32561 non-null  int64
#  12  Native_Country  32561 non-null  object
#  13  Income_Bracket  32561 non-null  object
# dtypes: int64(6), object(8)
# memory usage: 3.5+ MB

# %% [markdown]
# # task 2.2

# %% [markdown]
# # SUMMARISE OF DATA

# %%
data.describe().T
# Out:
#                   count           mean            std      min       25%  \
# Age             32561.0      38.581647      13.640433     17.0      28.0
# Fnlwgt          32561.0  189778.366512  105549.977697  12285.0  117827.0
# Education_Num   32561.0      10.080679       2.572720      1.0       9.0
# Capital_Gain    32561.0    1077.648844    7385.292085      0.0       0.0
# Capital_Loss    32561.0      87.303830     402.960219      0.0       0.0
# Hours_Per_Week  32561.0      40.437456      12.347429      1.0      40.0
#
#                      50%       75%        max
# Age                 37.0      48.0       90.0
# Fnlwgt          178356.0  237051.0  1484705.0
# Education_Num       10.0      12.0       16.0
# Capital_Gain         0.0       0.0    99999.0
# Capital_Loss         0.0       0.0     4356.0
# Hours_Per_Week      40.0      45.0       99.0

# %%
data.describe()
# Out:
#                 Age        Fnlwgt  Education_Num  Capital_Gain  Capital_Loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        Hours_Per_Week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# # task 3

# %% [markdown]
# # FIND THE MISSING VALUE IN THIS DATA SET

# %%
data.isnull().sum()
# Out:
# Age               0
# WorkClass         0
# Fnlwgt            0
# Education         0
# Education_Num     0
# Marital_Status    0
# Occupation        0
# Relationship      0
# Gender            0
# Capital_Gain      0
# Capital_Loss      0
# Hours_Per_Week    0
# Native_Country    0
# Income_Bracket    0
# dtype: int64

# %% [markdown]
# # task 3.2

# %% [markdown]
# # no missing value found in this data set

# %% [markdown]
# # task 4.1

# %% [markdown]
# # CONVERT THE NON NUMERICAL VALUE INTO CATEGORIES

# %%
data.columns
# Out:
# Index(['Age', 'WorkClass', 'Fnlwgt', 'Education', 'Education_Num',
#        'Marital_Status', 'Occupation', 'Relationship', 'Gender',
#        'Capital_Gain', 'Capital_Loss', 'Hours_Per_Week', 'Native_Country',
#        'Income_Bracket'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32561 non-null  int64
#  1   WorkClass       32561 non-null  object
#  2   Fnlwgt          32561 non-null  int64
#  3   Education       32561 non-null  object
#  4   Education_Num   32561 non-null  int64
#  5   Marital_Status  32561 non-null  object
#  6   Occupation      32561 non-null  object
#  7   Relationship    32561 non-null  object
#  8   Gender          32561 non-null  object
#  9   Capital_Gain    32561 non-null  int64
#  10  Capital_Loss    32561 non-null  int64
#  11  Hours_Per_Week  32561 non-null  int64
#  12  Native_Country  32561 non-null  object
#  13  Income_Bracket  32561 non-null  object
# dtypes: int64(6), object(8)
# memory usage: 3.5+ MB

# %%
data['WorkClass']=data['WorkClass'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 data['WorkClass']=data['WorkClass'].astype('int')
#
# File ~\anaconda3\New folder\lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\New folder\lib\site-packages\pandas\core\internals\managers.py:448, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
data['WorkClass']=data['WorkClass'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 data['WorkClass']=data['WorkClass'].astype('int')
#
# File ~\anaconda3\New folder\lib\site-packages\pandas\core\generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\New folder\lib\site-packages\pandas\core\internals\managers.py:448, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
data['WorkClass']=data['WorkClass'].astype('category')

# %%
data.columns
# Out:
# Index(['Age', 'WorkClass', 'Fnlwgt', 'Education', 'Education_Num',
#        'Marital_Status', 'Occupation', 'Relationship', 'Gender',
#        'Capital_Gain', 'Capital_Loss', 'Hours_Per_Week', 'Native_Country',
#        'Income_Bracket'],
#       dtype='object')

# %%
data['WorkClass']=data['WorkClass'].astype('category')
data['Education']=data['Education'].astype('category')
data['Marital_Status']=data['Marital_Status'].astype('category')

# %%
data['WorkClass']=data['WorkClass'].astype('category')
data['Education']=data['Education'].astype('category')
data['Marital_Status']=data['Marital_Status'].astype('category')
data['Occupation']=data['Occupation'].astype('category')
data['Relationship']=data['Relationship'].astype('category')
data['Gender']=data['Gender'].astype('category')
data['Native_Country']=data['Native_Country'].astype('category')
data['Income_Bracket']=data['Income_Bracket'].astype('category')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32561 non-null  int64
#  1   WorkClass       32561 non-null  category
#  2   Fnlwgt          32561 non-null  int64
#  3   Education       32561 non-null  object
#  4   Education_Num   32561 non-null  int64
#  5   Marital_Status  32561 non-null  object
#  6   Occupation      32561 non-null  object
#  7   Relationship    32561 non-null  object
#  8   Gender          32561 non-null  object
#  9   Capital_Gain    32561 non-null  int64
#  10  Capital_Loss    32561 non-null  int64
#  11  Hours_Per_Week  32561 non-null  int64
#  12  Native_Country  32561 non-null  object
#  13  Income_Bracket  32561 non-null  object
# dtypes: category(1), int64(6), object(7)
# memory usage: 3.3+ MB

# %% [markdown]
# # task 4.2

# %% [markdown]
# # CONVERT ALL THE CATEGORIES DATA INTO NUMERICAL VALUES

# %%
new_df=data

# %%
label=preprocessing.LabelEncoder()

# %%
from sklearn import preprocessing
from sklearn.model_selection import train_test_split

# %%
u=data

# %%
u
# Out:
#        Age  WorkClass  Fnlwgt  Education  Education_Num  Marital_Status  \
# 0       39          7   77516          9             13               4
# 1       50          6   83311          9             13               2
# 2       38          4  215646         11              9               0
# 3       53          4  234721          1              7               2
# 4       28          4  338409          9             13               2
# ...    ...        ...     ...        ...            ...             ...
# 32556   27          4  257302          7             12               2
# 32557   40          4  154374         11              9               2
# 32558   58          4  151910         11              9               6
# 32559   22          4  201490         11              9               4
# 32560   52          5  287927         11              9               2
#
#        Occupation  Relationship  Gender  Capital_Gain  Capital_Loss  \
# ...

# %%
label=preprocessing.LabelEncoder()
cat=u.select_dtypes(include=['object','category']).columns
for i in cat:
    u[i]=label.fit_transform(u[i])

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label=LabelEncoder()

# %%
u.head()
# Out:
#    Age  WorkClass  Fnlwgt  Education  Education_Num  Marital_Status  \
# 0   39          7   77516          9             13               4
# 1   50          6   83311          9             13               2
# 2   38          4  215646         11              9               0
# 3   53          4  234721          1              7               2
# 4   28          4  338409          9             13               2
#
#    Occupation  Relationship  Gender  Capital_Gain  Capital_Loss  \
# 0           1             1       1          2174             0
# 1           4             0       1             0             0
# 2           6             1       1             0             0
# 3           6             0       1             0             0
# 4          10             5       0             0             0
#
#    Hours_Per_Week  Native_Country  Income_Bracket
# 0              40              39               0
# 1              13              39               0
# ...

# %%
from sklearn import preprocessing

# %%
g=data

# %%
label=preprocessing.LabelEncoder()
cat=g.select_dtypes(include=['object','category']).columns
for i in cat:
    g[i]=label.fit_transform(g[i])

# %%
g.head()
# Out:
#    Age  WorkClass  Fnlwgt  Education  Education_Num  Marital_Status  \
# 0   39          7   77516          9             13               4
# 1   50          6   83311          9             13               2
# 2   38          4  215646         11              9               0
# 3   53          4  234721          1              7               2
# 4   28          4  338409          9             13               2
#
#    Occupation  Relationship  Gender  Capital_Gain  Capital_Loss  \
# 0           1             1       1          2174             0
# 1           4             0       1             0             0
# 2           6             1       1             0             0
# 3           6             0       1             0             0
# 4          10             5       0             0             0
#
#    Hours_Per_Week  Native_Country  Income_Bracket
# 0              40              39               0
# 1              13              39               0
# ...

# %%
label=preprocessing.LabelEncoder()
cat=new_df.select_dtypes(include=['object','category']).columns
for i in cat:
    new_df[i]=label.fit_transform(new_df[i])

# %%
new_df.head()
# Out:
#    Age  WorkClass  Fnlwgt  Education  Education_Num  Marital_Status  \
# 0   39          7   77516          9             13               4
# 1   50          6   83311          9             13               2
# 2   38          4  215646         11              9               0
# 3   53          4  234721          1              7               2
# 4   28          4  338409          9             13               2
#
#    Occupation  Relationship  Gender  Capital_Gain  Capital_Loss  \
# 0           1             1       1          2174             0
# 1           4             0       1             0             0
# 2           6             1       1             0             0
# 3           6             0       1             0             0
# 4          10             5       0             0             0
#
#    Hours_Per_Week  Native_Country  Income_Bracket
# 0              40              39               0
# 1              13              39               0
# ...

# %% [markdown]
# # TASK 4.3

# %% [markdown]
# # PERFORM THE DATA SCALING

# %%
def feature_scaling(scale):
    new_d=data.select_dtypes(exclude=['object','category'])
    if scale=='minmax':
        scaler=preprocessing.MinMaxScaler()
    else:
        scaler=preprocessing.StandardScaler()
    df_scale=pd.DataFrame(scaler.fit_transform(new_d),columns=new_d.columns)
    return df_scale
        

final_df=feature_scaling('minmax')

# %%
final_df
# Out:
#             Age  WorkClass    Fnlwgt  Education  Education_Num  \
# 0      0.301370      0.875  0.044302   0.600000       0.800000
# 1      0.452055      0.750  0.048238   0.600000       0.800000
# 2      0.287671      0.500  0.138113   0.733333       0.533333
# 3      0.493151      0.500  0.151068   0.066667       0.400000
# 4      0.150685      0.500  0.221488   0.600000       0.800000
# ...         ...        ...       ...        ...            ...
# 32556  0.136986      0.500  0.166404   0.466667       0.733333
# 32557  0.315068      0.500  0.096500   0.733333       0.533333
# 32558  0.561644      0.500  0.094827   0.733333       0.533333
# 32559  0.068493      0.500  0.128499   0.733333       0.533333
# 32560  0.479452      0.625  0.187203   0.733333       0.533333
#
#        Marital_Status  Occupation  Relationship  Gender  Capital_Gain  \
# 0            0.666667    0.071429           0.2     1.0      0.021740
# ...

# %% [markdown]
# # TASK 4.4

# %% [markdown]
# # CORRELATION IN THIS DATA SET

# %%
u.corr()
# Out:
#                      Age  WorkClass    Fnlwgt  Education  Education_Num  \
# Age             1.000000   0.003787 -0.076646  -0.010508       0.036527
# WorkClass       0.003787   1.000000 -0.016656   0.023513       0.052085
# Fnlwgt         -0.076646  -0.016656  1.000000  -0.028145      -0.043195
# Education      -0.010508   0.023513 -0.028145   1.000000       0.359153
# Education_Num   0.036527   0.052085 -0.043195   0.359153       1.000000
# Marital_Status -0.266288  -0.064731  0.028153  -0.038407      -0.069304
# Occupation     -0.020947   0.254892  0.001597  -0.021260       0.109697
# Relationship   -0.263698  -0.090461  0.008931  -0.010876      -0.094153
# Gender          0.088832   0.095981  0.026858  -0.027356       0.012280
# Capital_Gain    0.077674   0.033835  0.000432   0.030046       0.122630
# Capital_Loss    0.057775   0.012216 -0.010252   0.016746       0.079923
# Hours_Per_Week  0.068756   0.138962 -0.018768   0.055510       0.148123
# ...

# %%
plt.heatmap(u.corr(),annot=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 plt.heatmap(u.corr(),annot=True)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'heatmap'

# %%
h=u.head()

# %%
sb.heatmap(h.corr(),annot=True)
# Out:
# <Axes: >

# %%
sb.heatmap(data.corr(),annot=True)

# %%
final_df.corr()
# Out:
#                      Age  WorkClass    Fnlwgt  Education  Education_Num  \
# Age             1.000000   0.003787 -0.076646  -0.010508       0.036527
# WorkClass       0.003787   1.000000 -0.016656   0.023513       0.052085
# Fnlwgt         -0.076646  -0.016656  1.000000  -0.028145      -0.043195
# Education      -0.010508   0.023513 -0.028145   1.000000       0.359153
# Education_Num   0.036527   0.052085 -0.043195   0.359153       1.000000
# Marital_Status -0.266288  -0.064731  0.028153  -0.038407      -0.069304
# Occupation     -0.020947   0.254892  0.001597  -0.021260       0.109697
# Relationship   -0.263698  -0.090461  0.008931  -0.010876      -0.094153
# Gender          0.088832   0.095981  0.026858  -0.027356       0.012280
# Capital_Gain    0.077674   0.033835  0.000432   0.030046       0.122630
# Capital_Loss    0.057775   0.012216 -0.010252   0.016746       0.079923
# Hours_Per_Week  0.068756   0.138962 -0.018768   0.055510       0.148123
# ...

# %%
data.corr()
# Out:
#                      Age    Fnlwgt  Education_Num  Capital_Gain  Capital_Loss  \
# Age             1.000000 -0.076646       0.036527      0.077674      0.057775
# Fnlwgt         -0.076646  1.000000      -0.043195      0.000432     -0.010252
# Education_Num   0.036527 -0.043195       1.000000      0.122630      0.079923
# Capital_Gain    0.077674  0.000432       0.122630      1.000000     -0.031615
# Capital_Loss    0.057775 -0.010252       0.079923     -0.031615      1.000000
# Hours_Per_Week  0.068756 -0.018768       0.148123      0.078409      0.054256
#
#                 Hours_Per_Week
# Age                   0.068756
# Fnlwgt               -0.018768
# Education_Num         0.148123
# Capital_Gain          0.078409
# Capital_Loss          0.054256
# Hours_Per_Week        1.000000

# %%
plt.figure(figsize=(17,8))
sb.heatmap(data.corr(),annot=True)
# Out:
# <Axes: >

# %%
plt.figure(figsize=(15,8))
sb.heatmap(final_df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # task 5.1

# %% [markdown]
# # SPLIT THE DATA INTO TRAIN SET TEST SET INTO 70.30 RATIO BY ROW AND INDEX

# %%
final_df.shape
# Out:
# (32561, 14)

# %%
sp_df=final_df

# %%
n=int(32561*0.7)
X_train=sp_df.iloc[:n,:]
X_test=sp_df.iloc[n+1:,:]

# %%
X_test.shape
# Out:
# (9768, 14)

# %% [markdown]
# # TASK 5.2

# %% [markdown]
# # SPLIT THE DATA INTO TRAIN SET TEST SET INTO 70.30 RATIO BY TRAIN_test_split

# %%
data.columns
# Out:
# Index(['Age', 'WorkClass', 'Fnlwgt', 'Education', 'Education_Num',
#        'Marital_Status', 'Occupation', 'Relationship', 'Gender',
#        'Capital_Gain', 'Capital_Loss', 'Hours_Per_Week', 'Native_Country',
#        'Income_Bracket'],
#       dtype='object')

# %%
y=u['Income_Bracket']
x=u
x_terain,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=1)

# %%
y=final_df['Income_Bracket']
x=final_df
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=100)

# %%
y=final_df['Income_Bracket']
X=final_df
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=.30,random_state=100)

# %%
X_train
# Out:
#             Age  WorkClass    Fnlwgt  Education  Education_Num  \
# 0      0.301370      0.875  0.044302   0.600000       0.800000
# 1      0.452055      0.750  0.048238   0.600000       0.800000
# 2      0.287671      0.500  0.138113   0.733333       0.533333
# 3      0.493151      0.500  0.151068   0.066667       0.400000
# 4      0.150685      0.500  0.221488   0.600000       0.800000
# ...         ...        ...       ...        ...            ...
# 22787  0.520548      0.125  0.013366   1.000000       0.600000
# 22788  0.054795      0.500  0.089186   1.000000       0.600000
# 22789  0.246575      0.500  0.110039   1.000000       0.600000
# 22790  0.191781      0.750  0.102054   0.133333       0.466667
# 22791  0.301370      0.625  0.244658   0.800000       0.866667
#
#        Marital_Status  Occupation  Relationship  Gender  Capital_Gain  \
# 0            0.666667    0.071429           0.2     1.0       0.02174
# ...

# %% [markdown]
# # TASK 6.1

# %% [markdown]
# # data visualization of children present in this data set

# %%
data.columns
# Out:
# Index(['Age', 'WorkClass', 'Fnlwgt', 'Education', 'Education_Num',
#        'Marital_Status', 'Occupation', 'Relationship', 'Gender',
#        'Capital_Gain', 'Capital_Loss', 'Hours_Per_Week', 'Native_Country',
#        'Income_Bracket'],
#       dtype='object')

# %%
c=data['final_df'].value_counts().index

# %%
d_ind=data['Income_Bracket'].value_counts().index
d_values=data['Income_Bracket'].value_counts().values
plt.pie(x=d_values,labels=d_ind,autopct='%.2f%%')
plt.show()

# %% [markdown]
# # TASK 6.2

# %% [markdown]
# # data visulation

# %%
new_loan_df = data.select_dtypes(exclude='object')
numeric_cols=new_loan_df.columns
num_cols=4
n_bins = 50

num_rows= int(len(numeric_cols)/num_cols)+1
fig, axs = plt.subplots(num_rows, num_cols, tight_layout=True,figsize=(20,10))
for col, ax in zip(numeric_cols,axs.flatten()[:len(numeric_cols)]):
    ax.hist(new_loan_df[col],bins=n_bins,density=True)
    ax.set_title(col)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 new_loan_df = data.select_dtypes(exclude='object')
#       2 numeric_cols=new_loan_df.columns
#       3 num_cols=4
#
# NameError: name 'data' is not defined
