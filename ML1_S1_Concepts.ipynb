# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.model_selection import train_test_split
from sklearn import preprocessing #import as minmax_scale,StandardScaler,LabelEncoder
import sklearn.metrics as me
import warnings 
warnings.filterwarnings('ignore')

# %%
#from sklearn import preprocessing #standardization(feature scaling),normalization(feature scaling),LabelEnconder(convertion cat to num)

# %%
#sklearn.metrics#model evaluation accuracy

# %%
#import the data

# %%
df=pd.read_csv(r"D:\Batch-PT\L2_Machine_Learning\L2_C3_S1\DS2_C5_S1_Loan_Data_Concept (1).csv")

# %%
df.head()
# Out:
#    credit.policy             purpose  int.rate  installment  log.annual.inc  \
# 0              1  debt_consolidation    0.1189       829.10       11.350407
# 1              1         credit_card    0.1071       228.22       11.082143
# 2              1  debt_consolidation    0.1357       366.86       10.373491
# 3              1  debt_consolidation    0.1008       162.34       11.350407
# 4              1         credit_card    0.1426       102.92       11.299732
#
#      dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# 0  19.48   737        5639.958333      28854        52.1               0
# 1  14.29   707        2760.000000      33623        76.7               0
# 2  11.63   682        4710.000000       3511        25.6               1
# 3   8.10   712        2699.958333      33667        73.2               1
# 4  14.97   667        4066.000000       4740        39.5               0
#
#    delinq.2yrs  pub.rec  not.fully.paid
# ...

# %%
df.columns
# Out:
# Index(['credit.policy', 'purpose', 'int.rate', 'installment', 'log.annual.inc',
#        'dti', 'fico', 'days.with.cr.line', 'revol.bal', 'revol.util',
#        'inq.last.6mths', 'delinq.2yrs', 'pub.rec', 'not.fully.paid'],
#       dtype='object')

# %%
df.shape
# Out:
# (9578, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      9578 non-null   int64
#  1   purpose            9578 non-null   object
#  2   int.rate           9578 non-null   float64
#  3   installment        9578 non-null   float64
#  4   log.annual.inc     9578 non-null   float64
#  5   dti                9578 non-null   float64
#  6   fico               9578 non-null   int64
#  7   days.with.cr.line  9578 non-null   float64
#  8   revol.bal          9578 non-null   int64
#  9   revol.util         9578 non-null   float64
#  10  inq.last.6mths     9578 non-null   int64
#  11  delinq.2yrs        9578 non-null   int64
#  12  pub.rec            9578 non-null   int64
#  13  not.fully.paid     9578 non-null   int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %%
#missing value

# %%
df.isnull().sum()
# Out:
# credit.policy        0
# purpose              0
# int.rate             0
# installment          0
# log.annual.inc       0
# dti                  0
# fico                 0
# days.with.cr.line    0
# revol.bal            0
# revol.util           0
# inq.last.6mths       0
# delinq.2yrs          0
# pub.rec              0
# not.fully.paid       0
# dtype: int64

# %%
df.describe().T
# Out:
#                     count          mean           std         min  \
# credit.policy      9578.0      0.804970      0.396245    0.000000
# int.rate           9578.0      0.122640      0.026847    0.060000
# installment        9578.0    319.089413    207.071301   15.670000
# log.annual.inc     9578.0     10.932117      0.614813    7.547502
# dti                9578.0     12.606679      6.883970    0.000000
# fico               9578.0    710.846314     37.970537  612.000000
# days.with.cr.line  9578.0   4560.767197   2496.930377  178.958333
# revol.bal          9578.0  16913.963876  33756.189557    0.000000
# revol.util         9578.0     46.799236     29.014417    0.000000
# inq.last.6mths     9578.0      1.577469      2.200245    0.000000
# delinq.2yrs        9578.0      0.163708      0.546215    0.000000
# pub.rec            9578.0      0.062122      0.262126    0.000000
# not.fully.paid     9578.0      0.160054      0.366676    0.000000
#
# ...

# %%
df.select_dtypes(exclude='object')
# Out:
#       credit.policy  int.rate  installment  log.annual.inc    dti  fico  \
# 0                 1    0.1189       829.10       11.350407  19.48   737
# 1                 1    0.1071       228.22       11.082143  14.29   707
# 2                 1    0.1357       366.86       10.373491  11.63   682
# 3                 1    0.1008       162.34       11.350407   8.10   712
# 4                 1    0.1426       102.92       11.299732  14.97   667
# ...             ...       ...          ...             ...    ...   ...
# 9573              0    0.1461       344.76       12.180755  10.39   672
# 9574              0    0.1253       257.70       11.141862   0.21   722
# 9575              0    0.1071        97.81       10.596635  13.09   687
# 9576              0    0.1600       351.58       10.819778  19.18   692
# 9577              0    0.1392       853.43       11.264464  16.28   732
#
#       days.with.cr.line  revol.bal  revol.util  inq.last.6mths  delinq.2yrs  \
# ...

# %%
def num_cat(x):
    for i in x.columns:
        if x[i].nunique()<10:
            print(i,x[i].unique())

# %%
num_cat(df)
# Out:
# credit.policy [1 0]
# purpose ['debt_consolidation' 'credit_card' 'all_other' 'home_improvement'
#  'small_business' 'major_purchase' 'educational']
# pub.rec [0 1 2 3 4 5]
# not.fully.paid [0 1]

# %%
#Labelencoding

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      9578 non-null   int64
#  1   purpose            9578 non-null   object
#  2   int.rate           9578 non-null   float64
#  3   installment        9578 non-null   float64
#  4   log.annual.inc     9578 non-null   float64
#  5   dti                9578 non-null   float64
#  6   fico               9578 non-null   int64
#  7   days.with.cr.line  9578 non-null   float64
#  8   revol.bal          9578 non-null   int64
#  9   revol.util         9578 non-null   float64
#  10  inq.last.6mths     9578 non-null   int64
#  11  delinq.2yrs        9578 non-null   int64
#  12  pub.rec            9578 non-null   int64
#  13  not.fully.paid     9578 non-null   int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %%
lbl_end=preprocessing.LabelEncoder()#object of labelencoding
df['purpose']=lbl_end.fit_transform(df['purpose'])

# %%
df.head()
# Out:
#    credit.policy  purpose  int.rate  installment  log.annual.inc    dti  fico  \
# 0              1        2    0.1189       829.10       11.350407  19.48   737
# 1              1        1    0.1071       228.22       11.082143  14.29   707
# 2              1        2    0.1357       366.86       10.373491  11.63   682
# 3              1        2    0.1008       162.34       11.350407   8.10   712
# 4              1        1    0.1426       102.92       11.299732  14.97   667
#
#    days.with.cr.line  revol.bal  revol.util  inq.last.6mths  delinq.2yrs  \
# 0        5639.958333      28854        52.1               0            0
# 1        2760.000000      33623        76.7               0            0
# 2        4710.000000       3511        25.6               1            0
# 3        2699.958333      33667        73.2               1            0
# 4        4066.000000       4740        39.5               0            1
#
#    pub.rec  not.fully.paid  end_purpose
# ...

# %%
def feature_scaling(scale):
    new_df=df.select_dtypes(exclude=['object','category'])
    if scale=='minmax':
        scaler=preprocessing.MinMaxScaler()
    else:
        scaler=preprocessing.StandardScaler()
    df_scale=pd.DataFrame(scaler.fit_transform(new_df),columns=new_df.columns)
    return df_scale
        

final_df=feature_scaling('minmax')
final_df.head()
# Out:
#    credit.policy   purpose  int.rate  installment  log.annual.inc       dti  \
# 0            1.0  0.333333  0.376598     0.879888        0.544762  0.650200
# 1            1.0  0.166667  0.301151     0.229916        0.506334  0.476969
# 2            1.0  0.333333  0.484015     0.379883        0.404820  0.388184
# 3            1.0  0.333333  0.260870     0.158653        0.544762  0.270360
# 4            1.0  0.166667  0.528133     0.094378        0.537503  0.499666
#
#        fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# 0  0.581395           0.312754   0.023898    0.437815        0.000000
# 1  0.441860           0.147818   0.027848    0.644538        0.000000
# 2  0.325581           0.259495   0.002908    0.215126        0.030303
# 3  0.465116           0.144379   0.027885    0.615126        0.030303
# 4  0.255814           0.222613   0.003926    0.331933        0.000000
#
#    delinq.2yrs  pub.rec  not.fully.paid  end_purpose
# ...
